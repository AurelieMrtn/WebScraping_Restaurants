# %% [markdown]
# # **Scrap-Website-Example**
#
# In this first work I will try to scrap the list of seasonal fruits and vegetables from the website: https://www.lesfruitsetlegumesfrais.com/

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.lesfruitsetlegumesfrais.com/calendrier-fruits-legumes/fevrier')
html_content = response.content

soup = BeautifulSoup(html_content, 'html.parser')

# Find all span elements with the class 'name'
names = soup.find_all('span', class_='name')

# Extract the text from each span element
for name in names:
    print(name.text)
# Out:
# Chou rouge
# Champignon de paris
# Salade
# Oignon Primeur
# Chou kale
# Rutabaga
# Choux de Bruxelles
# Topinambour
# Courges et potirons
# Herbes aromatiques fraîches
# Champignons cultivés
# Panais
# Laitue
# Mâche
# Pomme de terre
# Chicorée
# Cresson
# Endive
# Betterave
# Carotte
# Céleri-rave
# Navet
# Oignon
# Poireau
# Blette
# Céleri-branche
# Épinard
# Fenouil
# Patate douce
# Artichaut
# Germe de haricot mungo Soja vert
# Lentille
# Chou pommé
# Chou-fleur
# Brocoli
# Ail
# Échalote
# Mangue
# Physalis
# Pitaya
# Sapotille
# Grenade
# Mangoustan
# Fruit de la passion
# Ananas
# Anone
# Carambole
# Poire
# Pomme
# Kiwi
# Pignon de pin
# Noix
# Noix de coco
# Clémentine, Mandarine
# Orange
# Pomelo
# Citron, Citron vert
# Truffe

# %%
import pandas as pd

columns = ["Janvier", "Fevrier", "Mars", "Avril", "Mai", "Juin", "Juillet", "Aout", "Septembre", "Octobre", "Novembre", "Decembre"]
seasonal_data = pd.DataFrame()
max_length = 0
data_dict = {}
print(seasonal_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for month in columns:
    url = 'https://www.lesfruitsetlegumesfrais.com/calendrier-fruits-legumes/'
    url = url + month.lower()
    
    response = requests.get(url)
    html_content = response.content
    soup = BeautifulSoup(html_content, 'html.parser')

    names = soup.find_all('span', class_='name')
    month_data = [name.text for name in names]
    
    # Update max_length if current list is longer
    if len(month_data) > max_length:
        max_length = len(month_data)
    
    data_dict[month] = month_data

# Now create the DataFrame with columns of equal length
for month, month_data in data_dict.items():
    # Pad month_data if it's not the longest one
    if len(month_data) < max_length:
        month_data += [None] * (max_length - len(month_data))
    seasonal_data[month] = month_data
    
seasonal_data
# Out:
#                 Janvier              Fevrier                 Mars  \
# 0            Chou rouge           Chou rouge  Champignon de paris
# 1   Champignon de paris  Champignon de paris               Salade
# 2                Salade               Salade       Oignon Primeur
# 3        Oignon Primeur       Oignon Primeur            Chou kale
# 4             Chou kale            Chou kale             Rutabaga
# ..                  ...                  ...                  ...
# 60               Truffe                 None                 None
# 61                 None                 None                 None
# 62                 None                 None                 None
# 63                 None                 None                 None
# 64                 None                 None                 None
#
#                    Avril                          Mai  \
# 0    Champignon de paris          Champignon de paris
# 1                 Salade                       Salade
# 2         Oignon Primeur              Carotte primeur
# 3               Rutabaga                  Topinambour
# 4   Champignons cultivés  Herbes aromatiques fraîches
# ..                   ...                          ...
# 60                  None                         None
# 61                  None                         None
# 62                  None                         None
# 63                  None                         None
# 64                  None                         None
#
#                            Juin                      Juillet  \
# 0                        Salade                       Salade
# 1               Carotte primeur                     Pastèque
# 2                      Pastèque  Herbes aromatiques fraîches
# 3   Herbes aromatiques fraîches                     Pourpier
# 4          Champignons cultivés                       Avocat
# ..                          ...                          ...
# 60                         None                         None
# 61                         None                         None
# 62                         None                         None
# 63                         None                         None
# 64                         None                         None
#
#                            Aout                    Septembre  \
# 0                        Salade          Champignon de paris
# 1                      Pastèque                       Salade
# 2   Herbes aromatiques fraîches               Oignon Primeur
# 3                      Pourpier           Choux de Bruxelles
# 4                     Betterave  Herbes aromatiques fraîches
# ..                          ...                          ...
# 60                         None                         None
# 61                         None                         None
# 62                         None                         None
# 63                         None                         None
# 64                         None                         None
#
#                 Octobre             Novembre               Decembre
# 0            Chou rouge           Chou rouge             Chou rouge
# 1   Champignon de paris  Champignon de paris    Champignon de paris
# 2                Salade               Salade                 Salade
# 3        Oignon Primeur       Oignon Primeur         Oignon Primeur
# 4             Chou kale            Chou kale              Chou kale
# ..                  ...                  ...                    ...
# 60               Amande               Orange  Clémentine, Mandarine
# 61            Châtaigne               Pomelo                 Orange
# 62             Rhubarbe               Truffe                 Pomelo
# 63               Truffe                 None    Citron, Citron vert
# 64                 None                 None                 Truffe
#
# [65 rows x 12 columns]
